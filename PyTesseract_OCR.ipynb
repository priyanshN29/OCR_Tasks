# %%
pip install pytesseract
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract

# %%
from PIL import Image

# %%
from matplotlib import pyplot as plt

# %%
import cv2

# %%
import numpy as np
from pytesseract import Output
import os

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img = cv2.imread('Invoice-Template2.jpg')
plt.imshow(img)

# %%
image_path = "Invoice-Template2.jpg"
img = Image.open(image_path)

# %%
text = pytesseract.image_to_string(Image.open(image_path))
print(text)
# Out:
# INVOICE
#
# BILL TO:
# Your Company Name Company Name
# Your Business Address Address
# City City
# Country Country
# Postal Postal
# INVOICE # DATE INVOICE DUE DATE AMOUNT DUE
#
# 123456 12/31/20 12/31/20 $0000.00
#
# ITEMS DESCRIPTION QUANTITY PRICE AMOUNT
# em 1 Description 3 00.00 0000.00
# em 2 Description 2 00.00 0000.00
# em 3 Description 3 00.00 0000.00
# em 4 Description 1 00.00 0000.00
# em 5 Description 1 00.00 0000.00
# em 6 Description 1 00.00 0000.00
# em7 Description 1 00.00 0000.00
# em 8 Description 1 00.00 0000.00
#
# NOTES: SUB-TOTAL $0000.00
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Praesent ut nisi TAX RATE 00%
#
# tempus massa blandit luctus.
#
# TAK $000.00
# TOTAL $0000.00
#
# This invoice was generated with the help of Wave Financial Inc. To learn more, and create your own free account visit waveapps.com Powered by ow) wave

# %%
# Image 2

img2 = cv2.imread('Tesseract Vs EasyOcr.png')
plt.imshow(img2)

# %%
image_path2 = "Tesseract Vs EasyOcr.png"
img2 = Image.open(image_path2)

# %%
text2 = pytesseract.image_to_string(Image.open(image_path2))
print(text2)
# Out:
# LAST Wednescry
#
# We had a pood
# Team building

# %%
# Image 3

img3 = cv2.imread('Optical Charac.png')
plt.imshow(img3)

# %%
image_path3 = "Optical Charac.png"
img3 = Image.open(image_path3)

# %%
text3 = pytesseract.image_to_string(Image.open(image_path3))
print(text3)
# Out:
# Reduce your risk of coronavirus infection:
#
# @ LA Clean hands with soap and water
# 442 or alcohol-based hand rub
#
# Cover nose and mouth when coughing and
# sneezing with tissue or flexed elbow
#
# Avoid close contact with anyone with
# cold or flu-like symptoms
#
# Thoroughly cook meat and eggs 7m
#
# - No unprotected contact with live wild
#
# 2B, wy or farm animals
#
# (fs) World Health
# # Organization
